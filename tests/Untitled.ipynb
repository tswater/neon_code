# %%
import matplotlib.pyplot as plt
import h5py
import rasterio
import os

# %%
checks=['BLAN','STER','STEI','SJER','YELL','OSBS','SOAP','LENO']
files='/home/tsw35/soteria/data/NEON/chm/_tifs/'

# %%
files='/home/tsw35/soteria/data/NEON/chm/_tifs/'
for file in os.listdir(files):
    if file[0:4] not in checks:
        continue
    plt.figure(figsize=(10,10))
    data=rasterio.open(files+file,'r').read(1)
    data[data<0]=float('nan')
    plt.imshow(data)
    plt.title(file)
    plt.colorbar()
# Out:
# /stor/soteria/hydro/private/tsw35/software/miniconda/envs/jenv/lib/python3.7/site-packages/ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in less
#   import sys

# %%
file='ABBY_chm.tif'
plt.figure()
data=rasterio.open(files+file,'r').read(1)
data[data<0]=float('nan')
r=200
data=data[5548-r:5548+r,2749-r:2749+r]
plt.imshow(data,vmin=0,vmax=np.max(data))
plt.colorbar()
import numpy as np
#print(np.mean(data[5548-500:5548+500,2749-500:2749+500]))
plt.scatter(100,100)
plt.title(file)
print(np.max(data))
print(np.median(data))
# Out:
# /stor/soteria/hydro/private/tsw35/software/miniconda/envs/jenv/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in less
#   after removing the cwd from sys.path.
# 49.747
# 4.658
